# %%
# !pip install pyautogui

# %%
import pyautogui
import time

pyautogui.PAUSE = 1

# Entrar no Sistema da Empresa (no link)
pyautogui.hotkey("ctrl","t")
pyautogui.write("LINK ONDE ESTÃO OS DADOS")
pyautogui.press("enter")
# Caso navegador tenha que carregar
time.sleep(5)


# Fazer Login

# FAZER LOGIN NO SITE DA EMPRESA

#(clicar no espaço de login)
pyautogui.click(x=1293, y=341)

#(escrever login)
pyautogui.write("meu_login")

#(clicar no espaço de senha)
pyautogui.click(x=1286, y=420)

#(escrever a senha)
pyautogui.write("minha_senha")

#(click para acessar)
pyautogui.click(x=1308, y=495)


# Passo 3: Exportar a Base de dados
pyautogui.click(x=482, y=429) # -> Clica no arquivo de compras
pyautogui.click(x=880, y=245) # -> clica nos 3 pontinhos
time.sleep(1)
pyautogui.click(x=991, y=753) # -> clica em fazer download
time.sleep(5)

# %%
# Calcular os Indicadores
import pandas as pd

tabela = pandas.read_csv(r"C:\Users\Wallace\Downloads\Compras.csv", sep=";")
display(tabela)

total_gasto = tabela["ValorFinal"].sum()
quantidade = tabela["Quantidade"].sum()
preco_medio = total_gasto / quantidade
print(total_gasto)
print(quantidade)
print(preco_medio)
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
# Enviar um e-mail para meu chefe

import pyperclip


# entrar no e-email: https://mail.google.com/mail/u/0/#inbox
pyautogui.hotkey("Ctrl","t")
pyautogui.write("https://mail.google.com/mail/u/0/#inbox")
pyautogui.press("enter")

time.sleep(5)


# clicar no botão de escrever
pyautogui.click(x=125, y=255)
time.sleep(2)

# destinatário
pyautogui.write("wallacegtr17@gmail.com")
pyautogui.press("tab")                      #escolher destinatário


# preencher as informações do e-mail
pyautogui.press("tab")

# Assunto do E-mail
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey ("Ctrl", "v")    # Colar o Texto

pyautogui.press("Tab")  # passando para o corpo do e-mail

texto = f"""
Prezados,
Segue o Relatório de compras

Total Gasto: R${total_gasto:,.2f}
Quantidade de Produtos: R${quantidade:,.2f}
Preço Médio: R${preco_medio:,.2f}

Qualquer dúvida, é só falar.
Att., Wallace Tosta

"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")

# enviar
pyautogui.hotkey("Ctrl", "Enter")
